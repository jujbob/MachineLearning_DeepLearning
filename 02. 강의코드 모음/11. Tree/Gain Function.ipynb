# %% [markdown]
# # 결정트리의 불순도와 정보이득을 계산하는 함수를 구현해보자

# %% [markdown]
# ## 1. 지니불순도
#  - 데이터가 분류되지 않고 섞여 있는 정도

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. 정보이득
#  - 결정트리에서 자식노드를 새로 만들면 얻을 수 있는 이득으로 자식노드를 만들어서 얼마나 분류를 더 잘하게되는가
#  - 즉 자식노드의 데이터 불순도가 작으면 작을 수록 커지게 됨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

parent_A = 1258
parent_B = 3939
left_child_A= 1177
left_child_B= 1745
right_child_A= 81
right_child_B= 2194


def gini(&&채워보세요&&):
  &&채워보세요&&
def information_gain(&&채워보세요&&):
  &&채워보세요&&

# %%
gini_parent = gini(&&채워보세요&&)
gini_parent
# Out:
# 0.3669367279393918

# %%
gini_child_l = gini(&&채워보세요&&)
gini_child_l
# Out:
# 0.481106768216382

# %%
gini_child_r = gini(&&채워보세요&&)
gini_child_r
# Out:
# 0.06867344523608265

# %%
information_gain(&&채워보세요&&)
# Out:
# 0.0663736983761137
